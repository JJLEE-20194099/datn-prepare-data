# %%
import pandas as pd

# %%
df = pd.read_csv('exp_mlops.csv')

# %%
df
# Out:
#     crawl data  clean data  insert data to database  build dataset  \
# 0    20.446524   22.925759                 3.338422      26.434431
# 1    19.309583   22.442677                 0.996875      30.813478
# 2    21.035960   22.291268                 1.002366      35.035311
# 3    18.730184   22.134425                 0.986362      37.679376
# 4    19.945734   23.056739                 2.321756      42.769500
# 5    21.203872   22.930342                 0.975409      31.746566
# 6    22.200940   22.943318                 1.000402      57.100556
# 7    21.811762   21.447932                 0.998039      74.889004
# 8    19.510429   21.937528                 2.625813      44.709613
# 9    19.905523   22.224158                 2.513975      42.498519
# 10   19.299287   23.091197                 0.995533      44.057190
# 11   19.320963   22.645140                 0.987787      56.530113
# 12   22.255111   22.401694                 1.008702      33.189562
# ...
